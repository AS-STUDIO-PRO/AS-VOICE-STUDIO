# %% [markdown]
# # 🚀 AS STUDIO - SETUP & INITIALIZATION
# Execute the cells below to install dependencies, setup, and launch the professional AS STUDIO web interface.

# %% [markdown]
# ### 📦 Step 1: Install Required Libraries
# AS STUDIO dependencies install karne ke liye is cell ko run karein.

# %%
# !pip install omnivoice gradio soundfile librosa

# %% [markdown]
# ### 🛠️ Step 2: Clone Project & Enter Directory

# %%
# !git clone https://github.com/AS-STUDIO-PRO/AS-VOICE-STUDIO.git
# %cd AS-VOICE-STUDIO

# %% [markdown]
# ### 🚀 Step 3: Launch Web Interface

# %%
# !python demo_AS_STUDIO.py --share
